# %% [markdown]
# <a href="https://colab.research.google.com/github/bhkpriyanka/EIP4/blob/master/Session5/LRFinder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# http://teleported.in/posts/cyclic-learning-rate/
# https://github.com/titu1994/keras-one-cycle/blob/master/clr.py

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q "/content/gdrive/My Drive/EIP4/Session5/hvc_data.zip"
# look for `hvc_annotations.csv` file and `resized` dir
# %ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# gdrive/  hvc_annotations.csv  resized/  sample_data/

# %%
import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

from matplotlib import pyplot as plt
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.layers.pooling import GlobalAveragePooling2D
from keras.regularizers import l2
from keras.applications import VGG16
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model, Sequential
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
batch_size = 32
#nb_classes = 10
nb_epoch = 1  # Only finding lr
data_augmentation = True

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15, random_state =1)
train_df.shape, val_df.shape
num_samples=train_df.shape[0]

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True, augmentation =None, subtract_pixel_mean=False):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation = augmentation
        self.subtract_pixel_mean = subtract_pixel_mean

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
        
        # If subtract pixel mean is enabled
        '''if self.subtract_pixel_mean:
          mean = []
          std  = []
          for i in range(image.shape[-1]):
            pixels = image[:, :, :, i].ravel()
            mean.append(np.mean(pixels))
            std.append(np.std(pixels))'''

        if self.augmentation is not None:
                 image = self.augmentation.flow(image,shuffle = False).next()

        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }
        return image, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
train_gen = PersonDataGenerator(train_df, batch_size=32,subtract_pixel_mean=False,
                            augmentation = ImageDataGenerator(horizontal_flip = True,rotation_range = 20, zoom_range = 0.2 ))
                                                          
valid_gen = PersonDataGenerator(val_df, batch_size=32, shuffle=False, subtract_pixel_mean=False)

# %%
n = 2
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 5 + 2

# %%
def resnet_layer(inputs,
                 num_filters=32,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth):
       
    if (depth - 2) % 5!= 0:
        raise ValueError('depth should be 4n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 32
    num_res_blocks = int((depth - 2) / 5)

    inputs = Input(shape=input_shape)
    
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(5):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    output = AveragePooling2D(pool_size=2)(x)
    #y = Flatten()(x)
    '''outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)'''

    # Instantiate model.
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
backbone = resnet_v1(input_shape= (224,224,3), depth=depth)

neck = backbone.output
neck = GlobalAveragePooling2D()(neck)
#neck = Flatten(name="flatten")(neck)
#neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = Dropout(0.1)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    #neck = Dropout(0.3)(in_layer)
    #neck = Dense(128, activation="relu")(neck)
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="softmax", name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)
opt = SGD(lr=0.001, momentum=0.9)
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 32) 9248        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 224, 224, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 224, 224, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 224, 224, 32) 9248        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 224, 224, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 224, 224, 32) 0           activation_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 224, 224, 32) 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 224, 224, 32) 9248        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 224, 224, 32) 128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 224, 224, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 224, 224, 32) 9248        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 224, 224, 32) 128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 224, 224, 32) 0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 224, 224, 32) 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 112, 112, 64) 18496       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 112, 112, 64) 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 112, 112, 64) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 112, 112, 64) 36928       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 112, 112, 64) 2112        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 112, 112, 64) 256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 112, 112, 64) 0           conv2d_8[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 112, 112, 64) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 112, 112, 64) 36928       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 112, 112, 64) 256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 112, 112, 64) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 112, 112, 64) 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 112, 112, 64) 256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 112, 112, 64) 0           activation_7[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 112, 112, 64) 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 56, 56, 128)  73856       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 56, 56, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 128)  8320        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 56, 56, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 56, 56, 128)  0           conv2d_13[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 56, 56, 128)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 56, 56, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 56, 56, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 56, 56, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 56, 56, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 56, 56, 128)  0           activation_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 56, 56, 128)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 256)  295168      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 256)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 28, 256)  590080      activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 256)  33024       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 28, 28, 256)  0           conv2d_18[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 256)  0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 256)  590080      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 256)  1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 256)  590080      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 256)  1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 28, 28, 256)  0           activation_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 256)  0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 512)  1180160     activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 14, 14, 512)  2048        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 14, 14, 512)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 512)  2359808     activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 512)  131584      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 14, 14, 512)  2048        conv2d_22[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 512)  0           conv2d_23[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 14, 14, 512)  0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 512)  2359808     activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 14, 14, 512)  2048        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 14, 14, 512)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 512)  2359808     activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 14, 14, 512)  2048        conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 512)  0           activation_19[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 14, 14, 512)  0           add_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 7, 7, 512)    0           activation_21[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512)          0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 512)          0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 512)          0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          65664       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          65664       dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          65664       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          65664       dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          65664       dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          65664       dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          65664       dropout_8[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          65664       dropout_7[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            258         dense_1[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            387         dense_2[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            645         dense_3[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            516         dense_4[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            387         dense_5[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            387         dense_6[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            387         dense_8[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            516         dense_7[0][0]
# ==================================================================================================
# Total params: 11,728,603
# Trainable params: 11,720,603
# Non-trainable params: 8,000
# __________________________________________________________________________________________________

# %%
from keras.callbacks import Callback
from keras import backend as K
import warnings
class LRFinder(Callback):
    def __init__(self,
                 num_samples,
                 batch_size,
                 minimum_lr=1e-5,
                 maximum_lr=10.,
                 lr_scale='exp',
                 validation_data=None,
                 validation_sample_rate=5,
                 stopping_criterion_factor=4.,
                 loss_smoothing_beta=0.98,
                 save_dir=None,
                 verbose=True):
        """
        This class uses the Cyclic Learning Rate history to find a
        set of learning rates that can be good initializations for the
        One-Cycle training proposed by Leslie Smith in the paper referenced
        below.
        A port of the Fast.ai implementation for Keras.
        # Note
        This requires that the model be trained for exactly 1 epoch. If the model
        is trained for more epochs, then the metric calculations are only done for
        the first epoch.
        # Interpretation
        Upon visualizing the loss plot, check where the loss starts to increase
        rapidly. Choose a learning rate at somewhat prior to the corresponding
        position in the plot for faster convergence. This will be the maximum_lr lr.
        Choose the max value as this value when passing the `max_val` argument
        to OneCycleLR callback.
        Since the plot is in log-scale, you need to compute 10 ^ (-k) of the x-axis
        # Arguments:
            num_samples: Integer. Number of samples in the dataset.
            batch_size: Integer. Batch size during training.
            minimum_lr: Float. Initial learning rate (and the minimum).
            maximum_lr: Float. Final learning rate (and the maximum).
            lr_scale: Can be one of ['exp', 'linear']. Chooses the type of
                scaling for each update to the learning rate during subsequent
                batches. Choose 'exp' for large range and 'linear' for small range.
            validation_data: Requires the validation dataset as a tuple of
                (X, y) belonging to the validation set. If provided, will use the
                validation set to compute the loss metrics. Else uses the training
                batch loss. Will warn if not provided to alert the user.
            validation_sample_rate: Positive or Negative Integer. Number of batches to sample from the
                validation set per iteration of the LRFinder. Larger number of
                samples will reduce the variance but will take longer time to execute
                per batch.
                If Positive > 0, will sample from the validation dataset
                If Megative, will use the entire dataset
            stopping_criterion_factor: Integer or None. A factor which is used
                to measure large increase in the loss value during training.
                Since callbacks cannot stop training of a model, it will simply
                stop logging the additional values from the epochs after this
                stopping criterion has been met.
                If None, this check will not be performed.
            loss_smoothing_beta: Float. The smoothing factor for the moving
                average of the loss function.
            save_dir: Optional, String. If passed a directory path, the callback
                will save the running loss and learning rates to two separate numpy
                arrays inside this directory. If the directory in this path does not
                exist, they will be created.
            verbose: Whether to print the learning rate after every batch of training.
        # References:
            - [A disciplined approach to neural network hyper-parameters: Part 1 -- learning rate, batch size, weight_decay, and weight decay](https://arxiv.org/abs/1803.09820)
        """
        super(LRFinder, self).__init__()

        if lr_scale not in ['exp', 'linear']:
            raise ValueError("`lr_scale` must be one of ['exp', 'linear']")

        if validation_data is not None:
            self.validation_data = validation_data
            self.use_validation_set = True

            if validation_sample_rate > 0 or validation_sample_rate < 0:
                self.validation_sample_rate = validation_sample_rate
            else:
                raise ValueError("`validation_sample_rate` must be a positive or negative integer other than o")
        else:
            self.use_validation_set = False
            self.validation_sample_rate = 0

        self.num_samples = num_samples
        self.batch_size = batch_size
        self.initial_lr = minimum_lr
        self.final_lr = maximum_lr
        self.lr_scale = lr_scale
        self.stopping_criterion_factor = stopping_criterion_factor
        self.loss_smoothing_beta = loss_smoothing_beta
        self.save_dir = save_dir
        self.verbose = verbose

        self.num_batches_ = num_samples // batch_size
        self.current_lr_ = minimum_lr

        if lr_scale == 'exp':
            self.lr_multiplier_ = (maximum_lr / float(minimum_lr)) ** (
                1. / float(self.num_batches_))
        else:
            extra_batch = int((num_samples % batch_size) != 0)
            self.lr_multiplier_ = np.linspace(
                minimum_lr, maximum_lr, num=self.num_batches_ + extra_batch)

        # If negative, use entire validation set
        if self.validation_sample_rate < 0:
            self.validation_sample_rate = self.validation_data[0].shape[0] // batch_size

        self.current_batch_ = 0
        self.current_epoch_ = 0
        self.best_loss_ = 1e6
        self.running_loss_ = 0.

        self.history = {}

    def on_train_begin(self, logs=None):

        self.current_epoch_ = 1
        K.set_value(self.model.optimizer.lr, self.initial_lr)

        warnings.simplefilter("ignore")

    def on_epoch_begin(self, epoch, logs=None):
        self.current_batch_ = 0

        if self.current_epoch_ > 1:
            warnings.warn(
                "\n\nLearning rate finder should be used only with a single epoch. "
                "Hereafter, the callback will not measure the losses.\n\n")

    def on_batch_begin(self, batch, logs=None):
        self.current_batch_ += 1

    def on_batch_end(self, batch, logs=None):
        if self.current_epoch_ > 1:
            return

        if self.use_validation_set:
            X, Y = self.validation_data[0], self.validation_data[1]

            # use 5 random batches from test set for fast approximate of loss
            num_samples = self.batch_size * self.validation_sample_rate

            if num_samples > X.shape[0]:
                num_samples = X.shape[0]

            idx = np.random.choice(X.shape[0], num_samples, replace=False)
            x = X[idx]
            y = Y[idx]

            values = self.model.evaluate(x, y, batch_size=self.batch_size, verbose=False)
            loss = values[0]
        else:
            loss = logs['loss']

        # smooth the loss value and bias correct
        running_loss = self.loss_smoothing_beta * loss + (
            1. - self.loss_smoothing_beta) * loss
        running_loss = running_loss / (
            1. - self.loss_smoothing_beta**self.current_batch_)

        # stop logging if loss is too large
        if self.current_batch_ > 1 and self.stopping_criterion_factor is not None and (
                running_loss >
                self.stopping_criterion_factor * self.best_loss_):

            if self.verbose:
                print(" - LRFinder: Skipping iteration since loss is %d times as large as best loss (%0.4f)"
                      % (self.stopping_criterion_factor, self.best_loss_))
            return

        if running_loss < self.best_loss_ or self.current_batch_ == 1:
            self.best_loss_ = running_loss

        current_lr = K.get_value(self.model.optimizer.lr)

        self.history.setdefault('running_loss_', []).append(running_loss)
        if self.lr_scale == 'exp':
            self.history.setdefault('log_lrs', []).append(np.log10(current_lr))
        else:
            self.history.setdefault('log_lrs', []).append(current_lr)

        # compute the lr for the next batch and update the optimizer lr
        if self.lr_scale == 'exp':
            current_lr *= self.lr_multiplier_
        else:
            current_lr = self.lr_multiplier_[self.current_batch_ - 1]

        K.set_value(self.model.optimizer.lr, current_lr)

        # save the other metrics as well
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

        if self.verbose:
            if self.use_validation_set:
                print(" - LRFinder: val_loss: %1.4f - lr = %1.8f " %
                      (values[0], current_lr))
            else:
                print(" - LRFinder: lr = %1.8f " % current_lr)

    def on_epoch_end(self, epoch, logs=None):
        if self.save_dir is not None and self.current_epoch_ <= 1:
            if not os.path.exists(self.save_dir):
                os.makedirs(self.save_dir)

            losses_path = os.path.join(self.save_dir, 'losses.npy')
            lrs_path = os.path.join(self.save_dir, 'lrs.npy')

            np.save(losses_path, self.losses)
            np.save(lrs_path, self.lrs)

            if self.verbose:
                print("\tLR Finder : Saved the losses and learning rate values in path : {%s}"
                      % (self.save_dir))

        self.current_epoch_ += 1

        warnings.simplefilter("default")

    def plot_schedule(self, clip_beginning=None, clip_endding=None):
        """
        Plots the schedule from the callback itself.
        # Arguments:
            clip_beginning: Integer or None. If positive integer, it will
                remove the specified portion of the loss graph to remove the large
                loss values in the beginning of the graph.
            clip_endding: Integer or None. If negative integer, it will
                remove the specified portion of the ending of the loss graph to
                remove the sharp increase in the loss values at high learning rates.
        """
        try:
            import matplotlib.pyplot as plt
            plt.style.use('seaborn-white')
        except ImportError:
            print(
                "Matplotlib not found. Please use `pip install matplotlib` first."
            )
            return

        if clip_beginning is not None and clip_beginning < 0:
            clip_beginning = -clip_beginning

        if clip_endding is not None and clip_endding > 0:
            clip_endding = -clip_endding

        losses = self.losses
        lrs = self.lrs

        if clip_beginning:
            losses = losses[clip_beginning:]
            lrs = lrs[clip_beginning:]

        if clip_endding:
            losses = losses[:clip_endding]
            lrs = lrs[:clip_endding]

        plt.plot(lrs, losses)
        plt.title('Learning rate vs Loss')
        plt.xlabel('learning rate')
        plt.ylabel('loss')
        plt.show()

    @classmethod
    def restore_schedule_from_dir(cls,
                                  directory,
                                  clip_beginning=None,
                                  clip_endding=None):
        """
        Loads the training history from the saved numpy files in the given directory.
        # Arguments:
            directory: String. Path to the directory where the serialized numpy
                arrays of the loss and learning rates are saved.
            clip_beginning: Integer or None. If positive integer, it will
                remove the specified portion of the loss graph to remove the large
                loss values in the beginning of the graph.
            clip_endding: Integer or None. If negative integer, it will
                remove the specified portion of the ending of the loss graph to
                remove the sharp increase in the loss values at high learning rates.
        Returns:
            tuple of (losses, learning rates)
        """
        if clip_beginning is not None and clip_beginning < 0:
            clip_beginning = -clip_beginning

        if clip_endding is not None and clip_endding > 0:
            clip_endding = -clip_endding

        losses_path = os.path.join(directory, 'losses.npy')
        lrs_path = os.path.join(directory, 'lrs.npy')

        if not os.path.exists(losses_path) or not os.path.exists(lrs_path):
            print("%s and %s could not be found at directory : {%s}" %
                  (losses_path, lrs_path, directory))

            losses = None
            lrs = None

        else:
            losses = np.load(losses_path)
            lrs = np.load(lrs_path)

            if clip_beginning:
                losses = losses[clip_beginning:]
                lrs = lrs[clip_beginning:]

            if clip_endding:
                losses = losses[:clip_endding]
                lrs = lrs[:clip_endding]

        return losses, lrs

    @classmethod
    def plot_schedule_from_file(cls,
                                directory,
                                clip_beginning=None,
                                clip_endding=None):
        """
        Plots the schedule from the saved numpy arrays of the loss and learning
        rate values in the specified directory.
        # Arguments:
            directory: String. Path to the directory where the serialized numpy
                arrays of the loss and learning rates are saved.
            clip_beginning: Integer or None. If positive integer, it will
                remove the specified portion of the loss graph to remove the large
                loss values in the beginning of the graph.
            clip_endding: Integer or None. If negative integer, it will
                remove the specified portion of the ending of the loss graph to
                remove the sharp increase in the loss values at high learning rates.
        """
        try:
            import matplotlib.pyplot as plt
            plt.style.use('seaborn-white')
        except ImportError:
            print("Matplotlib not found. Please use `pip install matplotlib` first.")
            return

        losses, lrs = cls.restore_schedule_from_dir(
            directory,
            clip_beginning=clip_beginning,
            clip_endding=clip_endding)

        if losses is None or lrs is None:
            return
        else:
            plt.plot(lrs, losses)
            plt.title('Learning rate vs Loss')
            plt.xlabel('learning rate')
            plt.ylabel('loss')
            plt.show()

    @property
    def lrs(self):
        return np.array(self.history['log_lrs'])

    @property
    def losses(self):
        return np.array(self.history['running_loss_'])

# %%
lr_finder = LRFinder(num_samples, batch_size, minimum_lr=1e-3, maximum_lr=10.,
                     lr_scale='exp',
                     # validation_data=(X_test, Y_test),  # use the validation data for losses
                     validation_sample_rate=5,
                     #save_dir='weights/', 
                     verbose=True)

# %%
# Ensure that number of epochs = 1 when calling fit()
# Fit the model on the batches generated by datagen.flow().
    model.fit_generator(generator=train_gen,
                        steps_per_epoch= num_samples // batch_size,
                        validation_data=valid_gen,
                        epochs=nb_epoch, verbose=1,
                        callbacks=[lr_finder])
# Out:
# Epoch 1/1
#   1/360 [..............................] - ETA: 5:25:11 - loss: 27.4168 - gender_output_loss: 2.0006 - image_quality_output_loss: 1.5024 - age_output_loss: 6.8743 - weight_output_loss: 5.0614 - bag_output_loss: 3.5682 - footwear_output_loss: 3.8219 - pose_output_loss: 1.7333 - emotion_output_loss: 1.8629 - gender_output_acc: 0.4688 - image_quality_output_acc: 0.3438 - age_output_acc: 0.0000e+00 - weight_output_acc: 0.0938 - bag_output_acc: 0.1562 - footwear_output_acc: 0.2188 - pose_output_acc: 0.5312 - emotion_output_acc: 0.1562 - LRFinder: lr = 0.00102591
#   2/360 [..............................] - ETA: 4:53:54 - loss: 22.9342 - gender_output_loss: 1.3538 - image_quality_output_loss: 1.3036 - age_output_loss: 5.0769 - weight_output_loss: 4.0706 - bag_output_loss: 2.9102 - footwear_output_loss: 3.8583 - pose_output_loss: 1.9271 - emotion_output_loss: 1.4416 - gender_output_acc: 0.5000 - image_quality_output_acc: 0.4219 - age_output_acc: 0.0469 - weight_output_acc: 0.0938 - bag_output_acc: 0.1719 - footwear_output_acc: 0.3125 - pose_output_acc: 0.5469 - emotion_output_acc: 0.3906     - LRFinder: lr = 0.00105250
#   3/360 [..............................] - ETA: 4:42:46 - loss: 19.7290 - gender_output_loss: 1.3362 - image_quality_output_loss: 1.2555 - age_output_loss: 3.9646 - weight_output_loss: 3.0956 - bag_output_loss: 2.2824 - footwear_output_loss: 3.4429 - pose_output_loss: 1.8771 - emotion_output_loss: 1.4826 - gender_output_acc: 0.5417 - image_quality_output_acc: 0.4792 - age_output_acc: 0.2083 - weight_output_acc: 0.2292 - bag_output_acc: 0.2812 - footwear_output_acc: 0.3750 - pose_output_acc: 0.5417 - emotion_output_acc: 0.4688 - LRFinder: lr = 0.00107978
#   4/360 [..............................] - ETA: 4:36:29 - loss: 18.7182 - gender_output_loss: 1.4906 - image_quality_output_loss: 1.2847 - age_output_loss: 3.6182 - weight_output_loss: 2.7229 - bag_output_loss: 2.3421 - footwear_output_loss: 3.0434 - pose_output_loss: 1.7138 - emotion_output_loss: 1.5103 - gender_output_acc: 0.5625 - image_quality_output_acc: 0.5000 - age_output_acc: 0.2344 - weight_output_acc: 0.3125 - bag_output_acc: 0.3203 - footwear_output_acc: 0.4062 - pose_output_acc: 0.5234 - emotion_output_acc: 0.5156 - LRFinder: lr = 0.00110776
#   5/360 [..............................] - ETA: 4:32:23 - loss: 17.7411 - gender_output_loss: 1.5472 - image_quality_output_loss: 1.2139 - age_output_loss: 3.2004 - weight_output_loss: 2.5462 - bag_output_loss: 2.2684 - footwear_output_loss: 2.7385 - pose_output_loss: 1.6493 - emotion_output_loss: 1.5853 - gender_output_acc: 0.5437 - image_quality_output_acc: 0.5000 - age_output_acc: 0.2687 - weight_output_acc: 0.3750 - bag_output_acc: 0.3750 - footwear_output_acc: 0.3875 - pose_output_acc: 0.4938 - emotion_output_acc: 0.5500 - LRFinder: lr = 0.00113646
#   6/360 [..............................] - ETA: 4:29:16 - loss: 17.2534 - gender_output_loss: 1.4576 - image_quality_output_loss: 1.2194 - age_output_loss: 3.0280 - weight_output_loss: 2.5810 - bag_output_loss: 2.2462 - footwear_output_loss: 2.6660 - pose_output_loss: 1.5541 - emotion_output_loss: 1.5093 - gender_output_acc: 0.5312 - image_quality_output_acc: 0.5052 - age_output_acc: 0.2708 - weight_output_acc: 0.4115 - bag_output_acc: 0.4062 - footwear_output_acc: 0.3854 - pose_output_acc: 0.4844 - emotion_output_acc: 0.5573 - LRFinder: lr = 0.00116591
#   7/360 [..............................] - ETA: 4:26:20 - loss: 16.7024 - gender_output_loss: 1.3678 - image_quality_output_loss: 1.1807 - age_output_loss: 2.9449 - weight_output_loss: 2.4544 - bag_output_loss: 2.1144 - footwear_output_loss: 2.6773 - pose_output_loss: 1.4743 - emotion_output_loss: 1.4965 - gender_output_acc: 0.5491 - image_quality_output_acc: 0.5179 - age_output_acc: 0.2857 - weight_output_acc: 0.4375 - bag_output_acc: 0.4196 - footwear_output_acc: 0.3705 - pose_output_acc: 0.5000 - emotion_output_acc: 0.5402 - LRFinder: lr = 0.00119613
#   8/360 [..............................] - ETA: 4:24:20 - loss: 16.2497 - gender_output_loss: 1.3226 - image_quality_output_loss: 1.1760 - age_output_loss: 2.8870 - weight_output_loss: 2.3253 - bag_output_loss: 1.9830 - footwear_output_loss: 2.5698 - pose_output_loss: 1.4876 - emotion_output_loss: 1.5063 - gender_output_acc: 0.5508 - image_quality_output_acc: 0.5156 - age_output_acc: 0.2852 - weight_output_acc: 0.4336 - bag_output_acc: 0.4219 - footwear_output_acc: 0.3555 - pose_output_acc: 0.5195 - emotion_output_acc: 0.5078 - LRFinder: lr = 0.00122713
#   9/360 [..............................] - ETA: 4:22:39 - loss: 15.8831 - gender_output_loss: 1.2981 - image_quality_output_loss: 1.1758 - age_output_loss: 2.8533 - weight_output_loss: 2.3140 - bag_output_loss: 1.9310 - footwear_output_loss: 2.3873 - pose_output_loss: 1.4302 - emotion_output_loss: 1.5015 - gender_output_acc: 0.5486 - image_quality_output_acc: 0.5104 - age_output_acc: 0.2882 - weight_output_acc: 0.4410 - bag_output_acc: 0.4167 - footwear_output_acc: 0.3819 - pose_output_acc: 0.5451 - emotion_output_acc: 0.5069 - LRFinder: lr = 0.00125893
#  10/360 [..............................] - ETA: 4:21:12 - loss: 15.5143 - gender_output_loss: 1.2752 - image_quality_output_loss: 1.1639 - age_output_loss: 2.7627 - weight_output_loss: 2.2168 - bag_output_loss: 1.8775 - footwear_output_loss: 2.3167 - pose_output_loss: 1.4707 - emotion_output_loss: 1.4388 - gender_output_acc: 0.5312 - image_quality_output_acc: 0.5156 - age_output_acc: 0.3000 - weight_output_acc: 0.4594 - bag_output_acc: 0.4156 - footwear_output_acc: 0.3844 - pose_output_acc: 0.5437 - emotion_output_acc: 0.5312 - LRFinder: lr = 0.00129155
#  11/360 [..............................] - ETA: 4:19:52 - loss: 15.0590 - gender_output_loss: 1.3076 - image_quality_output_loss: 1.1525 - age_output_loss: 2.6576 - weight_output_loss: 2.0713 - bag_output_loss: 1.8004 - footwear_output_loss: 2.2622 - pose_output_loss: 1.4387 - emotion_output_loss: 1.3767 - gender_output_acc: 0.5142 - image_quality_output_acc: 0.5170 - age_output_acc: 0.3153 - weight_output_acc: 0.4915 - bag_output_acc: 0.4176 - footwear_output_acc: 0.3892 - pose_output_acc: 0.5455 - emotion_output_acc: 0.5568 - LRFinder: lr = 0.00132502
#  12/360 [>.............................] - ETA: 4:18:35 - loss: 14.9289 - gender_output_loss: 1.3063 - image_quality_output_loss: 1.1420 - age_output_loss: 2.6411 - weight_output_loss: 2.0369 - bag_output_loss: 1.7324 - footwear_output_loss: 2.2086 - pose_output_loss: 1.4077 - emotion_output_loss: 1.4619 - gender_output_acc: 0.5156 - image_quality_output_acc: 0.5182 - age_output_acc: 0.3203 - weight_output_acc: 0.5000 - bag_output_acc: 0.4297 - footwear_output_acc: 0.3828 - pose_output_acc: 0.5391 - emotion_output_acc: 0.5521 - LRFinder: lr = 0.00135936
#  13/360 [>.............................] - ETA: 4:17:35 - loss: 14.5832 - gender_output_loss: 1.2474 - image_quality_output_loss: 1.1367 - age_output_loss: 2.5687 - weight_output_loss: 1.9637 - bag_output_loss: 1.6895 - footwear_output_loss: 2.1419 - pose_output_loss: 1.4135 - emotion_output_loss: 1.4301 - gender_output_acc: 0.5288 - image_quality_output_acc: 0.5264 - age_output_acc: 0.3221 - weight_output_acc: 0.5144 - bag_output_acc: 0.4399 - footwear_output_acc: 0.3678 - pose_output_acc: 0.5144 - emotion_output_acc: 0.5697 - LRFinder: lr = 0.00139458
#  14/360 [>.............................] - ETA: 4:16:30 - loss: 14.4673 - gender_output_loss: 1.2144 - image_quality_output_loss: 1.1424 - age_output_loss: 2.5339 - weight_output_loss: 1.9933 - bag_output_loss: 1.6838 - footwear_output_loss: 2.0984 - pose_output_loss: 1.4080 - emotion_output_loss: 1.4013 - gender_output_acc: 0.5268 - image_quality_output_acc: 0.5335 - age_output_acc: 0.3281 - weight_output_acc: 0.5201 - bag_output_acc: 0.4375 - footwear_output_acc: 0.3549 - pose_output_acc: 0.4888 - emotion_output_acc: 0.5826 - LRFinder: lr = 0.00143072
#  15/360 [>.............................] - ETA: 4:15:27 - loss: 14.2432 - gender_output_loss: 1.1822 - image_quality_output_loss: 1.1268 - age_output_loss: 2.4994 - weight_output_loss: 1.9793 - bag_output_loss: 1.6732 - footwear_output_loss: 2.0584 - pose_output_loss: 1.3835 - emotion_output_loss: 1.3486 - gender_output_acc: 0.5250 - image_quality_output_acc: 0.5375 - age_output_acc: 0.3187 - weight_output_acc: 0.5229 - bag_output_acc: 0.4354 - footwear_output_acc: 0.3479 - pose_output_acc: 0.4875 - emotion_output_acc: 0.6000 - LRFinder: lr = 0.00146780
#  16/360 [>.............................] - ETA: 4:14:29 - loss: 14.0760 - gender_output_loss: 1.1643 - image_quality_output_loss: 1.1185 - age_output_loss: 2.4820 - weight_output_loss: 1.9914 - bag_output_loss: 1.6428 - footwear_output_loss: 2.0040 - pose_output_loss: 1.3495 - emotion_output_loss: 1.3316 - gender_output_acc: 0.5137 - image_quality_output_acc: 0.5430 - age_output_acc: 0.3105 - weight_output_acc: 0.5137 - bag_output_acc: 0.4336 - footwear_output_acc: 0.3457 - pose_output_acc: 0.5000 - emotion_output_acc: 0.6035 - LRFinder: lr = 0.00150584
#  17/360 [>.............................] - ETA: 4:13:31 - loss: 13.9699 - gender_output_loss: 1.1398 - image_quality_output_loss: 1.1091 - age_output_loss: 2.4896 - weight_output_loss: 2.0013 - bag_output_loss: 1.6145 - footwear_output_loss: 1.9633 - pose_output_loss: 1.3460 - emotion_output_loss: 1.3144 - gender_output_acc: 0.5110 - image_quality_output_acc: 0.5423 - age_output_acc: 0.3088 - weight_output_acc: 0.5129 - bag_output_acc: 0.4320 - footwear_output_acc: 0.3456 - pose_output_acc: 0.5000 - emotion_output_acc: 0.6066 - LRFinder: lr = 0.00154486
#  18/360 [>.............................] - ETA: 4:12:36 - loss: 13.7546 - gender_output_loss: 1.1138 - image_quality_output_loss: 1.1038 - age_output_loss: 2.4579 - weight_output_loss: 1.9642 - bag_output_loss: 1.5828 - footwear_output_loss: 1.9081 - pose_output_loss: 1.3228 - emotion_output_loss: 1.3093 - gender_output_acc: 0.5208 - image_quality_output_acc: 0.5365 - age_output_acc: 0.3038 - weight_output_acc: 0.5174 - bag_output_acc: 0.4271 - footwear_output_acc: 0.3524 - pose_output_acc: 0.5087 - emotion_output_acc: 0.6024 - LRFinder: lr = 0.00158489
#  19/360 [>.............................] - ETA: 4:11:44 - loss: 13.5694 - gender_output_loss: 1.0995 - image_quality_output_loss: 1.0986 - age_output_loss: 2.3998 - weight_output_loss: 1.9491 - bag_output_loss: 1.5599 - footwear_output_loss: 1.8630 - pose_output_loss: 1.3068 - emotion_output_loss: 1.3009 - gender_output_acc: 0.5214 - image_quality_output_acc: 0.5362 - age_output_acc: 0.3059 - weight_output_acc: 0.5247 - bag_output_acc: 0.4194 - footwear_output_acc: 0.3536 - pose_output_acc: 0.5148 - emotion_output_acc: 0.6053 - LRFinder: lr = 0.00162596
#  20/360 [>.............................] - ETA: 4:10:52 - loss: 13.3971 - gender_output_loss: 1.0932 - image_quality_output_loss: 1.1028 - age_output_loss: 2.3632 - weight_output_loss: 1.9231 - bag_output_loss: 1.5377 - footwear_output_loss: 1.8261 - pose_output_loss: 1.2847 - emotion_output_loss: 1.2745 - gender_output_acc: 0.5172 - image_quality_output_acc: 0.5266 - age_output_acc: 0.3078 - weight_output_acc: 0.5266 - bag_output_acc: 0.4172 - footwear_output_acc: 0.3563 - pose_output_acc: 0.5250 - emotion_output_acc: 0.6156 - LRFinder: lr = 0.00166810
#  21/360 [>.............................] - ETA: 4:09:58 - loss: 13.2432 - gender_output_loss: 1.0773 - image_quality_output_loss: 1.1010 - age_output_loss: 2.3410 - weight_output_loss: 1.8899 - bag_output_loss: 1.5093 - footwear_output_loss: 1.7941 - pose_output_loss: 1.2806 - emotion_output_loss: 1.2582 - gender_output_acc: 0.5193 - image_quality_output_acc: 0.5238 - age_output_acc: 0.3125 - weight_output_acc: 0.5268 - bag_output_acc: 0.4196 - footwear_output_acc: 0.3571 - pose_output_acc: 0.5298 - emotion_output_acc: 0.6205 - LRFinder: lr = 0.00171133
#  22/360 [>.............................] - ETA: 4:09:04 - loss: 13.0708 - gender_output_loss: 1.0615 - image_quality_output_loss: 1.1022 - age_output_loss: 2.3074 - weight_output_loss: 1.8622 - bag_output_loss: 1.4870 - footwear_output_loss: 1.7632 - pose_output_loss: 1.2590 - emotion_output_loss: 1.2365 - gender_output_acc: 0.5227 - image_quality_output_acc: 0.5213 - age_output_acc: 0.3196 - weight_output_acc: 0.5312 - bag_output_acc: 0.4247 - footwear_output_acc: 0.3636 - pose_output_acc: 0.5398 - emotion_output_acc: 0.6264 - LRFinder: lr = 0.00175568
#  23/360 [>.............................] - ETA: 4:08:15 - loss: 12.9364 - gender_output_loss: 1.0407 - image_quality_output_loss: 1.0983 - age_output_loss: 2.2737 - weight_output_loss: 1.8253 - bag_output_loss: 1.4763 - footwear_output_loss: 1.7418 - pose_output_loss: 1.2492 - emotion_output_loss: 1.2392 - gender_output_acc: 0.5326 - image_quality_output_acc: 0.5245 - age_output_acc: 0.3247 - weight_output_acc: 0.5367 - bag_output_acc: 0.4212 - footwear_output_acc: 0.3655 - pose_output_acc: 0.5421 - emotion_output_acc: 0.6264 - LRFinder: lr = 0.00180117
#  24/360 [=>............................] - ETA: 4:07:26 - loss: 12.7995 - gender_output_loss: 1.0293 - image_quality_output_loss: 1.0950 - age_output_loss: 2.2463 - weight_output_loss: 1.7884 - bag_output_loss: 1.4573 - footwear_output_loss: 1.7201 - pose_output_loss: 1.2455 - emotion_output_loss: 1.2258 - gender_output_acc: 0.5286 - image_quality_output_acc: 0.5234 - age_output_acc: 0.3307 - weight_output_acc: 0.5482 - bag_output_acc: 0.4271 - footwear_output_acc: 0.3685 - pose_output_acc: 0.5430 - emotion_output_acc: 0.6328 - LRFinder: lr = 0.00184785
#  25/360 [=>............................] - ETA: 4:06:39 - loss: 12.6663 - gender_output_loss: 1.0201 - image_quality_output_loss: 1.0897 - age_output_loss: 2.2166 - weight_output_loss: 1.7575 - bag_output_loss: 1.4498 - footwear_output_loss: 1.6940 - pose_output_loss: 1.2390 - emotion_output_loss: 1.2078 - gender_output_acc: 0.5262 - image_quality_output_acc: 0.5250 - age_output_acc: 0.3325 - weight_output_acc: 0.5500 - bag_output_acc: 0.4263 - footwear_output_acc: 0.3750 - pose_output_acc: 0.5437 - emotion_output_acc: 0.6388 - LRFinder: lr = 0.00189574
#  26/360 [=>............................] - ETA: 4:05:54 - loss: 12.5802 - gender_output_loss: 1.0114 - image_quality_output_loss: 1.0955 - age_output_loss: 2.1984 - weight_output_loss: 1.7367 - bag_output_loss: 1.4345 - footwear_output_loss: 1.6704 - pose_output_loss: 1.2266 - emotion_output_loss: 1.2151 - gender_output_acc: 0.5252 - image_quality_output_acc: 0.5228 - age_output_acc: 0.3293 - weight_output_acc: 0.5529 - bag_output_acc: 0.4291 - footwear_output_acc: 0.3798 - pose_output_acc: 0.5481 - emotion_output_acc: 0.6370 - LRFinder: lr = 0.00194486
#  27/360 [=>............................] - ETA: 4:05:09 - loss: 12.4426 - gender_output_loss: 0.9996 - image_quality_output_loss: 1.0933 - age_output_loss: 2.1708 - weight_output_loss: 1.7049 - bag_output_loss: 1.4198 - footwear_output_loss: 1.6434 - pose_output_loss: 1.2283 - emotion_output_loss: 1.1909 - gender_output_acc: 0.5278 - image_quality_output_acc: 0.5255 - age_output_acc: 0.3345 - weight_output_acc: 0.5590 - bag_output_acc: 0.4317 - footwear_output_acc: 0.3889 - pose_output_acc: 0.5451 - emotion_output_acc: 0.6470 - LRFinder: lr = 0.00199526
#  28/360 [=>............................] - ETA: 4:04:21 - loss: 12.3378 - gender_output_loss: 0.9884 - image_quality_output_loss: 1.0903 - age_output_loss: 2.1518 - weight_output_loss: 1.6860 - bag_output_loss: 1.4033 - footwear_output_loss: 1.6226 - pose_output_loss: 1.2189 - emotion_output_loss: 1.1848 - gender_output_acc: 0.5301 - image_quality_output_acc: 0.5268 - age_output_acc: 0.3315 - weight_output_acc: 0.5603 - bag_output_acc: 0.4364 - footwear_output_acc: 0.3906 - pose_output_acc: 0.5502 - emotion_output_acc: 0.6484 - LRFinder: lr = 0.00204697
#  29/360 [=>............................] - ETA: 4:03:33 - loss: 12.2509 - gender_output_loss: 0.9835 - image_quality_output_loss: 1.0919 - age_output_loss: 2.1337 - weight_output_loss: 1.6726 - bag_output_loss: 1.3853 - footwear_output_loss: 1.6056 - pose_output_loss: 1.2113 - emotion_output_loss: 1.1753 - gender_output_acc: 0.5269 - image_quality_output_acc: 0.5216 - age_output_acc: 0.3297 - weight_output_acc: 0.5571 - bag_output_acc: 0.4429 - footwear_output_acc: 0.3901 - pose_output_acc: 0.5517 - emotion_output_acc: 0.6476 - LRFinder: lr = 0.00210001
#  30/360 [=>............................] - ETA: 4:02:43 - loss: 12.1410 - gender_output_loss: 0.9740 - image_quality_output_loss: 1.0852 - age_output_loss: 2.1126 - weight_output_loss: 1.6454 - bag_output_loss: 1.3698 - footwear_output_loss: 1.5897 - pose_output_loss: 1.2022 - emotion_output_loss: 1.1704 - gender_output_acc: 0.5271 - image_quality_output_acc: 0.5250 - age_output_acc: 0.3292 - weight_output_acc: 0.5625 - bag_output_acc: 0.4479 - footwear_output_acc: 0.3906 - pose_output_acc: 0.5542 - emotion_output_acc: 0.6469 - LRFinder: lr = 0.00215443
#  31/360 [=>............................] - ETA: 4:01:54 - loss: 12.0331 - gender_output_loss: 0.9626 - image_quality_output_loss: 1.0791 - age_output_loss: 2.0894 - weight_output_loss: 1.6191 - bag_output_loss: 1.3575 - footwear_output_loss: 1.5737 - pose_output_loss: 1.1951 - emotion_output_loss: 1.1650 - gender_output_acc: 0.5323 - image_quality_output_acc: 0.5262 - age_output_acc: 0.3296 - weight_output_acc: 0.5696 - bag_output_acc: 0.4496 - footwear_output_acc: 0.3921 - pose_output_acc: 0.5554 - emotion_output_acc: 0.6492 - LRFinder: lr = 0.00221026
#  32/360 [=>............................] - ETA: 4:01:07 - loss: 11.9385 - gender_output_loss: 0.9552 - image_quality_output_loss: 1.0776 - age_output_loss: 2.0727 - weight_output_loss: 1.5982 - bag_output_loss: 1.3401 - footwear_output_loss: 1.5575 - pose_output_loss: 1.1908 - emotion_output_loss: 1.1546 - gender_output_acc: 0.5312 - image_quality_output_acc: 0.5273 - age_output_acc: 0.3301 - weight_output_acc: 0.5732 - bag_output_acc: 0.4570 - footwear_output_acc: 0.3926 - pose_output_acc: 0.5566 - emotion_output_acc: 0.6533 - LRFinder: lr = 0.00226754
#  33/360 [=>............................] - ETA: 4:00:18 - loss: 11.8524 - gender_output_loss: 0.9489 - image_quality_output_loss: 1.0703 - age_output_loss: 2.0562 - weight_output_loss: 1.5846 - bag_output_loss: 1.3296 - footwear_output_loss: 1.5410 - pose_output_loss: 1.1835 - emotion_output_loss: 1.1464 - gender_output_acc: 0.5312 - image_quality_output_acc: 0.5303 - age_output_acc: 0.3305 - weight_output_acc: 0.5720 - bag_output_acc: 0.4602 - footwear_output_acc: 0.3958 - pose_output_acc: 0.5597 - emotion_output_acc: 0.6553 - LRFinder: lr = 0.00232630
#  34/360 [=>............................] - ETA: 3:59:32 - loss: 11.7876 - gender_output_loss: 0.9448 - image_quality_output_loss: 1.0659 - age_output_loss: 2.0404 - weight_output_loss: 1.5670 - bag_output_loss: 1.3231 - footwear_output_loss: 1.5300 - pose_output_loss: 1.1787 - emotion_output_loss: 1.1459 - gender_output_acc: 0.5303 - image_quality_output_acc: 0.5312 - age_output_acc: 0.3327 - weight_output_acc: 0.5744 - bag_output_acc: 0.4614 - footwear_output_acc: 0.3915 - pose_output_acc: 0.5634 - emotion_output_acc: 0.6553 - LRFinder: lr = 0.00238659
#  35/360 [=>............................] - ETA: 3:58:50 - loss: 11.7246 - gender_output_loss: 0.9398 - image_quality_output_loss: 1.0743 - age_output_loss: 2.0292 - weight_output_loss: 1.5555 - bag_output_loss: 1.3128 - footwear_output_loss: 1.5145 - pose_output_loss: 1.1735 - emotion_output_loss: 1.1334 - gender_output_acc: 0.5277 - image_quality_output_acc: 0.5286 - age_output_acc: 0.3330 - weight_output_acc: 0.5759 - bag_output_acc: 0.4652 - footwear_output_acc: 0.3920 - pose_output_acc: 0.5652 - emotion_output_acc: 0.6598 - LRFinder: lr = 0.00244844
#  36/360 [==>...........................] - ETA: 3:58:10 - loss: 11.6532 - gender_output_loss: 0.9354 - image_quality_output_loss: 1.0735 - age_output_loss: 2.0113 - weight_output_loss: 1.5423 - bag_output_loss: 1.3062 - footwear_output_loss: 1.5044 - pose_output_loss: 1.1619 - emotion_output_loss: 1.1266 - gender_output_acc: 0.5252 - image_quality_output_acc: 0.5304 - age_output_acc: 0.3368 - weight_output_acc: 0.5773 - bag_output_acc: 0.4670 - footwear_output_acc: 0.3941 - pose_output_acc: 0.5694 - emotion_output_acc: 0.6632 - LRFinder: lr = 0.00251189
#  37/360 [==>...........................] - ETA: 3:57:23 - loss: 11.5729 - gender_output_loss: 0.9291 - image_quality_output_loss: 1.0723 - age_output_loss: 1.9945 - weight_output_loss: 1.5282 - bag_output_loss: 1.2978 - footwear_output_loss: 1.4891 - pose_output_loss: 1.1581 - emotion_output_loss: 1.1121 - gender_output_acc: 0.5236 - image_quality_output_acc: 0.5312 - age_output_acc: 0.3412 - weight_output_acc: 0.5802 - bag_output_acc: 0.4696 - footwear_output_acc: 0.3953 - pose_output_acc: 0.5709 - emotion_output_acc: 0.6681 - LRFinder: lr = 0.00257698
#  38/360 [==>...........................] - ETA: 3:56:36 - loss: 11.5047 - gender_output_loss: 0.9235 - image_quality_output_loss: 1.0690 - age_output_loss: 1.9746 - weight_output_loss: 1.5117 - bag_output_loss: 1.2899 - footwear_output_loss: 1.4756 - pose_output_loss: 1.1554 - emotion_output_loss: 1.1134 - gender_output_acc: 0.5271 - image_quality_output_acc: 0.5337 - age_output_acc: 0.3470 - weight_output_acc: 0.5839 - bag_output_acc: 0.4704 - footwear_output_acc: 0.3980 - pose_output_acc: 0.5724 - emotion_output_acc: 0.6686 - LRFinder: lr = 0.00264376
#  39/360 [==>...........................] - ETA: 3:55:47 - loss: 11.4347 - gender_output_loss: 0.9200 - image_quality_output_loss: 1.0661 - age_output_loss: 1.9609 - weight_output_loss: 1.4944 - bag_output_loss: 1.2800 - footwear_output_loss: 1.4634 - pose_output_loss: 1.1466 - emotion_output_loss: 1.1117 - gender_output_acc: 0.5264 - image_quality_output_acc: 0.5385 - age_output_acc: 0.3486 - weight_output_acc: 0.5857 - bag_output_acc: 0.4720 - footwear_output_acc: 0.4014 - pose_output_acc: 0.5769 - emotion_output_acc: 0.6691 - LRFinder: lr = 0.00271227
#  40/360 [==>...........................] - ETA: 3:55:00 - loss: 11.3748 - gender_output_loss: 0.9182 - image_quality_output_loss: 1.0659 - age_output_loss: 1.9502 - weight_output_loss: 1.4791 - bag_output_loss: 1.2705 - footwear_output_loss: 1.4523 - pose_output_loss: 1.1391 - emotion_output_loss: 1.1077 - gender_output_acc: 0.5250 - image_quality_output_acc: 0.5383 - age_output_acc: 0.3492 - weight_output_acc: 0.5875 - bag_output_acc: 0.4734 - footwear_output_acc: 0.4016 - pose_output_acc: 0.5797 - emotion_output_acc: 0.6695 - LRFinder: lr = 0.00278256
#  41/360 [==>...........................] - ETA: 3:54:13 - loss: 11.3110 - gender_output_loss: 0.9114 - image_quality_output_loss: 1.0670 - age_output_loss: 1.9420 - weight_output_loss: 1.4616 - bag_output_loss: 1.2621 - footwear_output_loss: 1.4375 - pose_output_loss: 1.1377 - emotion_output_loss: 1.1001 - gender_output_acc: 0.5274 - image_quality_output_acc: 0.5358 - age_output_acc: 0.3476 - weight_output_acc: 0.5907 - bag_output_acc: 0.4710 - footwear_output_acc: 0.4062 - pose_output_acc: 0.5800 - emotion_output_acc: 0.6723 - LRFinder: lr = 0.00285467
#  42/360 [==>...........................] - ETA: 3:53:27 - loss: 11.2499 - gender_output_loss: 0.9043 - image_quality_output_loss: 1.0612 - age_output_loss: 1.9314 - weight_output_loss: 1.4506 - bag_output_loss: 1.2524 - footwear_output_loss: 1.4284 - pose_output_loss: 1.1346 - emotion_output_loss: 1.0954 - gender_output_acc: 0.5298 - image_quality_output_acc: 0.5409 - age_output_acc: 0.3475 - weight_output_acc: 0.5908 - bag_output_acc: 0.4702 - footwear_output_acc: 0.4077 - pose_output_acc: 0.5796 - emotion_output_acc: 0.6749 - LRFinder: lr = 0.00292864
#  43/360 [==>...........................] - ETA: 3:52:40 - loss: 11.2005 - gender_output_loss: 0.8993 - image_quality_output_loss: 1.0616 - age_output_loss: 1.9211 - weight_output_loss: 1.4406 - bag_output_loss: 1.2422 - footwear_output_loss: 1.4210 - pose_output_loss: 1.1307 - emotion_output_loss: 1.0925 - gender_output_acc: 0.5305 - image_quality_output_acc: 0.5400 - age_output_acc: 0.3459 - weight_output_acc: 0.5908 - bag_output_acc: 0.4724 - footwear_output_acc: 0.4070 - pose_output_acc: 0.5821 - emotion_output_acc: 0.6737 - LRFinder: lr = 0.00300454
#  44/360 [==>...........................] - ETA: 3:51:43 - loss: 11.1506 - gender_output_loss: 0.8954 - image_quality_output_loss: 1.0604 - age_output_loss: 1.9109 - weight_output_loss: 1.4360 - bag_output_loss: 1.2351 - footwear_output_loss: 1.4090 - pose_output_loss: 1.1273 - emotion_output_loss: 1.0849 - gender_output_acc: 0.5291 - image_quality_output_acc: 0.5398 - age_output_acc: 0.3445 - weight_output_acc: 0.5895 - bag_output_acc: 0.4759 - footwear_output_acc: 0.4126 - pose_output_acc: 0.5831 - emotion_output_acc: 0.6776 - LRFinder: lr = 0.00308240
#  45/360 [==>...........................] - ETA: 3:50:47 - loss: 11.0942 - gender_output_loss: 0.8890 - image_quality_output_loss: 1.0559 - age_output_loss: 1.8993 - weight_output_loss: 1.4317 - bag_output_loss: 1.2246 - footwear_output_loss: 1.3994 - pose_output_loss: 1.1240 - emotion_output_loss: 1.0786 - gender_output_acc: 0.5326 - image_quality_output_acc: 0.5410 - age_output_acc: 0.3431 - weight_output_acc: 0.5868 - bag_output_acc: 0.4806 - footwear_output_acc: 0.4139 - pose_output_acc: 0.5819 - emotion_output_acc: 0.6799 - LRFinder: lr = 0.00316228
#  46/360 [==>...........................] - ETA: 3:49:53 - loss: 11.0618 - gender_output_loss: 0.8840 - image_quality_output_loss: 1.0538 - age_output_loss: 1.8894 - weight_output_loss: 1.4303 - bag_output_loss: 1.2214 - footwear_output_loss: 1.3946 - pose_output_loss: 1.1222 - emotion_output_loss: 1.0745 - gender_output_acc: 0.5353 - image_quality_output_acc: 0.5408 - age_output_acc: 0.3410 - weight_output_acc: 0.5856 - bag_output_acc: 0.4796 - footwear_output_acc: 0.4158 - pose_output_acc: 0.5808 - emotion_output_acc: 0.6814 - LRFinder: lr = 0.00324423
#  47/360 [==>...........................] - ETA: 3:48:59 - loss: 11.0428 - gender_output_loss: 0.8793 - image_quality_output_loss: 1.0538 - age_output_loss: 1.8813 - weight_output_loss: 1.4283 - bag_output_loss: 1.2245 - footwear_output_loss: 1.3884 - pose_output_loss: 1.1164 - emotion_output_loss: 1.0792 - gender_output_acc: 0.5379 - image_quality_output_acc: 0.5366 - age_output_acc: 0.3398 - weight_output_acc: 0.5831 - bag_output_acc: 0.4787 - footwear_output_acc: 0.4142 - pose_output_acc: 0.5838 - emotion_output_acc: 0.6802 - LRFinder: lr = 0.00332830
#  48/360 [===>..........................] - ETA: 3:48:04 - loss: 10.9876 - gender_output_loss: 0.8751 - image_quality_output_loss: 1.0505 - age_output_loss: 1.8709 - weight_output_loss: 1.4193 - bag_output_loss: 1.2168 - footwear_output_loss: 1.3801 - pose_output_loss: 1.1106 - emotion_output_loss: 1.0727 - gender_output_acc: 0.5365 - image_quality_output_acc: 0.5371 - age_output_acc: 0.3398 - weight_output_acc: 0.5833 - bag_output_acc: 0.4785 - footwear_output_acc: 0.4147 - pose_output_acc: 0.5866 - emotion_output_acc: 0.6829 - LRFinder: lr = 0.00341455
#  49/360 [===>..........................] - ETA: 3:47:10 - loss: 10.9600 - gender_output_loss: 0.8702 - image_quality_output_loss: 1.0586 - age_output_loss: 1.8638 - weight_output_loss: 1.4075 - bag_output_loss: 1.2099 - footwear_output_loss: 1.3732 - pose_output_loss: 1.1105 - emotion_output_loss: 1.0747 - gender_output_acc: 0.5389 - image_quality_output_acc: 0.5312 - age_output_acc: 0.3412 - weight_output_acc: 0.5855 - bag_output_acc: 0.4809 - footwear_output_acc: 0.4145 - pose_output_acc: 0.5855 - emotion_output_acc: 0.6824 - LRFinder: lr = 0.00350303
#  50/360 [===>..........................] - ETA: 3:46:17 - loss: 10.9166 - gender_output_loss: 0.8660 - image_quality_output_loss: 1.0550 - age_output_loss: 1.8561 - weight_output_loss: 1.3992 - bag_output_loss: 1.2036 - footwear_output_loss: 1.3659 - pose_output_loss: 1.1073 - emotion_output_loss: 1.0720 - gender_output_acc: 0.5425 - image_quality_output_acc: 0.5325 - age_output_acc: 0.3425 - weight_output_acc: 0.5869 - bag_output_acc: 0.4825 - footwear_output_acc: 0.4138 - pose_output_acc: 0.5869 - emotion_output_acc: 0.6825 - LRFinder: lr = 0.00359381
#  51/360 [===>..........................] - ETA: 3:45:23 - loss: 10.8824 - gender_output_loss: 0.8625 - image_quality_output_loss: 1.0553 - age_output_loss: 1.8458 - weight_output_loss: 1.3885 - bag_output_loss: 1.2019 - footwear_output_loss: 1.3591 - pose_output_loss: 1.1056 - emotion_output_loss: 1.0721 - gender_output_acc: 0.5429 - image_quality_output_acc: 0.5319 - age_output_acc: 0.3456 - weight_output_acc: 0.5895 - bag_output_acc: 0.4828 - footwear_output_acc: 0.4167 - pose_output_acc: 0.5876 - emotion_output_acc: 0.6838 - LRFinder: lr = 0.00368694
#  52/360 [===>..........................] - ETA: 3:44:31 - loss: 10.8521 - gender_output_loss: 0.8592 - image_quality_output_loss: 1.0559 - age_output_loss: 1.8382 - weight_output_loss: 1.3845 - bag_output_loss: 1.1964 - footwear_output_loss: 1.3516 - pose_output_loss: 1.1012 - emotion_output_loss: 1.0736 - gender_output_acc: 0.5415 - image_quality_output_acc: 0.5319 - age_output_acc: 0.3462 - weight_output_acc: 0.5883 - bag_output_acc: 0.4832 - footwear_output_acc: 0.4201 - pose_output_acc: 0.5895 - emotion_output_acc: 0.6833 - LRFinder: lr = 0.00378249
#  53/360 [===>..........................] - ETA: 3:43:38 - loss: 10.8142 - gender_output_loss: 0.8544 - image_quality_output_loss: 1.0551 - age_output_loss: 1.8298 - weight_output_loss: 1.3811 - bag_output_loss: 1.1885 - footwear_output_loss: 1.3443 - pose_output_loss: 1.0981 - emotion_output_loss: 1.0714 - gender_output_acc: 0.5454 - image_quality_output_acc: 0.5330 - age_output_acc: 0.3473 - weight_output_acc: 0.5867 - bag_output_acc: 0.4864 - footwear_output_acc: 0.4233 - pose_output_acc: 0.5902 - emotion_output_acc: 0.6828 - LRFinder: lr = 0.00388051
#  54/360 [===>..........................] - ETA: 3:42:46 - loss: 10.7845 - gender_output_loss: 0.8520 - image_quality_output_loss: 1.0560 - age_output_loss: 1.8226 - weight_output_loss: 1.3730 - bag_output_loss: 1.1811 - footwear_output_loss: 1.3388 - pose_output_loss: 1.0940 - emotion_output_loss: 1.0754 - gender_output_acc: 0.5463 - image_quality_output_acc: 0.5324 - age_output_acc: 0.3501 - weight_output_acc: 0.5868 - bag_output_acc: 0.4867 - footwear_output_acc: 0.4259 - pose_output_acc: 0.5920 - emotion_output_acc: 0.6788 - LRFinder: lr = 0.00398107
#  55/360 [===>..........................] - ETA: 3:41:55 - loss: 10.7566 - gender_output_loss: 0.8488 - image_quality_output_loss: 1.0584 - age_output_loss: 1.8191 - weight_output_loss: 1.3635 - bag_output_loss: 1.1794 - footwear_output_loss: 1.3326 - pose_output_loss: 1.0923 - emotion_output_loss: 1.0709 - gender_output_acc: 0.5472 - image_quality_output_acc: 0.5307 - age_output_acc: 0.3500 - weight_output_acc: 0.5898 - bag_output_acc: 0.4847 - footwear_output_acc: 0.4284 - pose_output_acc: 0.5920 - emotion_output_acc: 0.6807 - LRFinder: lr = 0.00408424
#  56/360 [===>..........................] - ETA: 3:41:04 - loss: 10.7289 - gender_output_loss: 0.8471 - image_quality_output_loss: 1.0561 - age_output_loss: 1.8166 - weight_output_loss: 1.3582 - bag_output_loss: 1.1734 - footwear_output_loss: 1.3272 - pose_output_loss: 1.0889 - emotion_output_loss: 1.0700 - gender_output_acc: 0.5480 - image_quality_output_acc: 0.5324 - age_output_acc: 0.3488 - weight_output_acc: 0.5910 - bag_output_acc: 0.4877 - footwear_output_acc: 0.4302 - pose_output_acc: 0.5932 - emotion_output_acc: 0.6797 - LRFinder: lr = 0.00419008
#  57/360 [===>..........................] - ETA: 3:40:12 - loss: 10.7024 - gender_output_loss: 0.8435 - image_quality_output_loss: 1.0549 - age_output_loss: 1.8124 - weight_output_loss: 1.3501 - bag_output_loss: 1.1688 - footwear_output_loss: 1.3176 - pose_output_loss: 1.0882 - emotion_output_loss: 1.0753 - gender_output_acc: 0.5493 - image_quality_output_acc: 0.5329 - age_output_acc: 0.3492 - weight_output_acc: 0.5921 - bag_output_acc: 0.4890 - footwear_output_acc: 0.4359 - pose_output_acc: 0.5916 - emotion_output_acc: 0.6765 - LRFinder: lr = 0.00429866
#  58/360 [===>..........................] - ETA: 3:39:23 - loss: 10.6760 - gender_output_loss: 0.8409 - image_quality_output_loss: 1.0528 - age_output_loss: 1.8097 - weight_output_loss: 1.3443 - bag_output_loss: 1.1624 - footwear_output_loss: 1.3090 - pose_output_loss: 1.0867 - emotion_output_loss: 1.0785 - gender_output_acc: 0.5501 - image_quality_output_acc: 0.5345 - age_output_acc: 0.3475 - weight_output_acc: 0.5938 - bag_output_acc: 0.4908 - footwear_output_acc: 0.4402 - pose_output_acc: 0.5911 - emotion_output_acc: 0.6751 - LRFinder: lr = 0.00441006
#  59/360 [===>..........................] - ETA: 3:38:32 - loss: 10.6508 - gender_output_loss: 0.8392 - image_quality_output_loss: 1.0501 - age_output_loss: 1.8043 - weight_output_loss: 1.3394 - bag_output_loss: 1.1582 - footwear_output_loss: 1.3024 - pose_output_loss: 1.0840 - emotion_output_loss: 1.0817 - gender_output_acc: 0.5514 - image_quality_output_acc: 0.5355 - age_output_acc: 0.3469 - weight_output_acc: 0.5943 - bag_output_acc: 0.4910 - footwear_output_acc: 0.4417 - pose_output_acc: 0.5922 - emotion_output_acc: 0.6748 - LRFinder: lr = 0.00452434
#  60/360 [====>.........................] - ETA: 3:37:43 - loss: 10.6254 - gender_output_loss: 0.8369 - image_quality_output_loss: 1.0489 - age_output_loss: 1.7998 - weight_output_loss: 1.3314 - bag_output_loss: 1.1529 - footwear_output_loss: 1.2978 - pose_output_loss: 1.0855 - emotion_output_loss: 1.0807 - gender_output_acc: 0.5510 - image_quality_output_acc: 0.5359 - age_output_acc: 0.3453 - weight_output_acc: 0.5964 - bag_output_acc: 0.4922 - footwear_output_acc: 0.4443 - pose_output_acc: 0.5896 - emotion_output_acc: 0.6755 - LRFinder: lr = 0.00464159
#  61/360 [====>.........................] - ETA: 3:36:54 - loss: 10.5947 - gender_output_loss: 0.8348 - image_quality_output_loss: 1.0479 - age_output_loss: 1.7919 - weight_output_loss: 1.3249 - bag_output_loss: 1.1487 - footwear_output_loss: 1.2960 - pose_output_loss: 1.0821 - emotion_output_loss: 1.0769 - gender_output_acc: 0.5517 - image_quality_output_acc: 0.5379 - age_output_acc: 0.3468 - weight_output_acc: 0.5978 - bag_output_acc: 0.4928 - footwear_output_acc: 0.4426 - pose_output_acc: 0.5902 - emotion_output_acc: 0.6767 - LRFinder: lr = 0.00476187
#  62/360 [====>.........................] - ETA: 3:36:06 - loss: 10.5681 - gender_output_loss: 0.8326 - image_quality_output_loss: 1.0488 - age_output_loss: 1.7880 - weight_output_loss: 1.3215 - bag_output_loss: 1.1426 - footwear_output_loss: 1.2912 - pose_output_loss: 1.0810 - emotion_output_loss: 1.0709 - gender_output_acc: 0.5519 - image_quality_output_acc: 0.5383 - age_output_acc: 0.3463 - weight_output_acc: 0.5983 - bag_output_acc: 0.4950 - footwear_output_acc: 0.4441 - pose_output_acc: 0.5892 - emotion_output_acc: 0.6789 - LRFinder: lr = 0.00488527
#  63/360 [====>.........................] - ETA: 3:35:18 - loss: 10.5587 - gender_output_loss: 0.8317 - image_quality_output_loss: 1.0479 - age_output_loss: 1.7836 - weight_output_loss: 1.3184 - bag_output_loss: 1.1409 - footwear_output_loss: 1.2881 - pose_output_loss: 1.0801 - emotion_output_loss: 1.0764 - gender_output_acc: 0.5516 - image_quality_output_acc: 0.5392 - age_output_acc: 0.3472 - weight_output_acc: 0.5982 - bag_output_acc: 0.4955 - footwear_output_acc: 0.4444 - pose_output_acc: 0.5893 - emotion_output_acc: 0.6766 - LRFinder: lr = 0.00501187
#  64/360 [====>.........................] - ETA: 3:34:30 - loss: 10.5376 - gender_output_loss: 0.8299 - image_quality_output_loss: 1.0512 - age_output_loss: 1.7811 - weight_output_loss: 1.3106 - bag_output_loss: 1.1366 - footwear_output_loss: 1.2830 - pose_output_loss: 1.0757 - emotion_output_loss: 1.0781 - gender_output_acc: 0.5522 - image_quality_output_acc: 0.5381 - age_output_acc: 0.3472 - weight_output_acc: 0.5991 - bag_output_acc: 0.4985 - footwear_output_acc: 0.4468 - pose_output_acc: 0.5913 - emotion_output_acc: 0.6758 - LRFinder: lr = 0.00514175
#  65/360 [====>.........................] - ETA: 3:33:42 - loss: 10.5179 - gender_output_loss: 0.8270 - image_quality_output_loss: 1.0500 - age_output_loss: 1.7766 - weight_output_loss: 1.3099 - bag_output_loss: 1.1337 - footwear_output_loss: 1.2802 - pose_output_loss: 1.0722 - emotion_output_loss: 1.0767 - gender_output_acc: 0.5529 - image_quality_output_acc: 0.5385 - age_output_acc: 0.3486 - weight_output_acc: 0.5976 - bag_output_acc: 0.4981 - footwear_output_acc: 0.4466 - pose_output_acc: 0.5933 - emotion_output_acc: 0.6760 - LRFinder: lr = 0.00527500
#  66/360 [====>.........................] - ETA: 3:32:54 - loss: 10.4940 - gender_output_loss: 0.8249 - image_quality_output_loss: 1.0495 - age_output_loss: 1.7724 - weight_output_loss: 1.3041 - bag_output_loss: 1.1291 - footwear_output_loss: 1.2763 - pose_output_loss: 1.0703 - emotion_output_loss: 1.0761 - gender_output_acc: 0.5530 - image_quality_output_acc: 0.5374 - age_output_acc: 0.3490 - weight_output_acc: 0.5966 - bag_output_acc: 0.4995 - footwear_output_acc: 0.4470 - pose_output_acc: 0.5942 - emotion_output_acc: 0.6757 - LRFinder: lr = 0.00541169
#  67/360 [====>.........................] - ETA: 3:32:06 - loss: 10.4770 - gender_output_loss: 0.8229 - image_quality_output_loss: 1.0502 - age_output_loss: 1.7671 - weight_output_loss: 1.3011 - bag_output_loss: 1.1258 - footwear_output_loss: 1.2732 - pose_output_loss: 1.0709 - emotion_output_loss: 1.0744 - gender_output_acc: 0.5522 - image_quality_output_acc: 0.5359 - age_output_acc: 0.3507 - weight_output_acc: 0.5951 - bag_output_acc: 0.4995 - footwear_output_acc: 0.4464 - pose_output_acc: 0.5933 - emotion_output_acc: 0.6768 - LRFinder: lr = 0.00555193
#  68/360 [====>.........................] - ETA: 3:31:18 - loss: 10.4594 - gender_output_loss: 0.8203 - image_quality_output_loss: 1.0517 - age_output_loss: 1.7633 - weight_output_loss: 1.3001 - bag_output_loss: 1.1226 - footwear_output_loss: 1.2705 - pose_output_loss: 1.0686 - emotion_output_loss: 1.0708 - gender_output_acc: 0.5519 - image_quality_output_acc: 0.5335 - age_output_acc: 0.3493 - weight_output_acc: 0.5947 - bag_output_acc: 0.5005 - footwear_output_acc: 0.4458 - pose_output_acc: 0.5942 - emotion_output_acc: 0.6788 - LRFinder: lr = 0.00569581
#  69/360 [====>.........................] - ETA: 3:30:35 - loss: 10.4354 - gender_output_loss: 0.8180 - image_quality_output_loss: 1.0518 - age_output_loss: 1.7588 - weight_output_loss: 1.2955 - bag_output_loss: 1.1202 - footwear_output_loss: 1.2678 - pose_output_loss: 1.0664 - emotion_output_loss: 1.0654 - gender_output_acc: 0.5521 - image_quality_output_acc: 0.5303 - age_output_acc: 0.3505 - weight_output_acc: 0.5960 - bag_output_acc: 0.5000 - footwear_output_acc: 0.4443 - pose_output_acc: 0.5942 - emotion_output_acc: 0.6807 - LRFinder: lr = 0.00584341
#  70/360 [====>.........................] - ETA: 3:29:54 - loss: 10.4116 - gender_output_loss: 0.8173 - image_quality_output_loss: 1.0501 - age_output_loss: 1.7564 - weight_output_loss: 1.2900 - bag_output_loss: 1.1175 - footwear_output_loss: 1.2638 - pose_output_loss: 1.0642 - emotion_output_loss: 1.0609 - gender_output_acc: 0.5509 - image_quality_output_acc: 0.5326 - age_output_acc: 0.3500 - weight_output_acc: 0.5973 - bag_output_acc: 0.4978 - footwear_output_acc: 0.4455 - pose_output_acc: 0.5946 - emotion_output_acc: 0.6821 - LRFinder: lr = 0.00599484
#  71/360 [====>.........................] - ETA: 3:29:12 - loss: 10.3929 - gender_output_loss: 0.8161 - image_quality_output_loss: 1.0483 - age_output_loss: 1.7514 - weight_output_loss: 1.2880 - bag_output_loss: 1.1156 - footwear_output_loss: 1.2596 - pose_output_loss: 1.0607 - emotion_output_loss: 1.0618 - gender_output_acc: 0.5506 - image_quality_output_acc: 0.5339 - age_output_acc: 0.3490 - weight_output_acc: 0.5968 - bag_output_acc: 0.4987 - footwear_output_acc: 0.4481 - pose_output_acc: 0.5964 - emotion_output_acc: 0.6822 - LRFinder: lr = 0.00615019
#  72/360 [=====>........................] - ETA: 3:28:30 - loss: 10.3784 - gender_output_loss: 0.8145 - image_quality_output_loss: 1.0499 - age_output_loss: 1.7474 - weight_output_loss: 1.2815 - bag_output_loss: 1.1127 - footwear_output_loss: 1.2564 - pose_output_loss: 1.0584 - emotion_output_loss: 1.0660 - gender_output_acc: 0.5508 - image_quality_output_acc: 0.5334 - age_output_acc: 0.3494 - weight_output_acc: 0.5990 - bag_output_acc: 0.4978 - footwear_output_acc: 0.4488 - pose_output_acc: 0.5972 - emotion_output_acc: 0.6814 - LRFinder: lr = 0.00630957
#  73/360 [=====>........................] - ETA: 3:27:47 - loss: 10.3593 - gender_output_loss: 0.8131 - image_quality_output_loss: 1.0507 - age_output_loss: 1.7415 - weight_output_loss: 1.2743 - bag_output_loss: 1.1101 - footwear_output_loss: 1.2543 - pose_output_loss: 1.0571 - emotion_output_loss: 1.0667 - gender_output_acc: 0.5497 - image_quality_output_acc: 0.5338 - age_output_acc: 0.3523 - weight_output_acc: 0.6015 - bag_output_acc: 0.4970 - footwear_output_acc: 0.4482 - pose_output_acc: 0.5972 - emotion_output_acc: 0.6815 - LRFinder: lr = 0.00647308
#  74/360 [=====>........................] - ETA: 3:27:05 - loss: 10.3542 - gender_output_loss: 0.8117 - image_quality_output_loss: 1.0502 - age_output_loss: 1.7408 - weight_output_loss: 1.2723 - bag_output_loss: 1.1090 - footwear_output_loss: 1.2513 - pose_output_loss: 1.0565 - emotion_output_loss: 1.0710 - gender_output_acc: 0.5486 - image_quality_output_acc: 0.5342 - age_output_acc: 0.3526 - weight_output_acc: 0.6018 - bag_output_acc: 0.4979 - footwear_output_acc: 0.4489 - pose_output_acc: 0.5976 - emotion_output_acc: 0.6799 - LRFinder: lr = 0.00664083
#  75/360 [=====>........................] - ETA: 3:26:22 - loss: 10.3403 - gender_output_loss: 0.8103 - image_quality_output_loss: 1.0492 - age_output_loss: 1.7392 - weight_output_loss: 1.2681 - bag_output_loss: 1.1058 - footwear_output_loss: 1.2504 - pose_output_loss: 1.0573 - emotion_output_loss: 1.0687 - gender_output_acc: 0.5492 - image_quality_output_acc: 0.5346 - age_output_acc: 0.3525 - weight_output_acc: 0.6029 - bag_output_acc: 0.4992 - footwear_output_acc: 0.4483 - pose_output_acc: 0.5967 - emotion_output_acc: 0.6804 - LRFinder: lr = 0.00681292
#  76/360 [=====>........................] - ETA: 3:25:39 - loss: 10.3238 - gender_output_loss: 0.8094 - image_quality_output_loss: 1.0492 - age_output_loss: 1.7352 - weight_output_loss: 1.2652 - bag_output_loss: 1.1034 - footwear_output_loss: 1.2479 - pose_output_loss: 1.0536 - emotion_output_loss: 1.0685 - gender_output_acc: 0.5489 - image_quality_output_acc: 0.5329 - age_output_acc: 0.3536 - weight_output_acc: 0.6032 - bag_output_acc: 0.5008 - footwear_output_acc: 0.4474 - pose_output_acc: 0.5987 - emotion_output_acc: 0.6797 - LRFinder: lr = 0.00698947
#  77/360 [=====>........................] - ETA: 3:24:56 - loss: 10.3065 - gender_output_loss: 0.8075 - image_quality_output_loss: 1.0473 - age_output_loss: 1.7323 - weight_output_loss: 1.2605 - bag_output_loss: 1.1002 - footwear_output_loss: 1.2445 - pose_output_loss: 1.0542 - emotion_output_loss: 1.0684 - gender_output_acc: 0.5499 - image_quality_output_acc: 0.5349 - age_output_acc: 0.3531 - weight_output_acc: 0.6043 - bag_output_acc: 0.5028 - footwear_output_acc: 0.4489 - pose_output_acc: 0.5978 - emotion_output_acc: 0.6798 - LRFinder: lr = 0.00717060
#  78/360 [=====>........................] - ETA: 3:24:14 - loss: 10.2908 - gender_output_loss: 0.8059 - image_quality_output_loss: 1.0474 - age_output_loss: 1.7306 - weight_output_loss: 1.2587 - bag_output_loss: 1.0956 - footwear_output_loss: 1.2434 - pose_output_loss: 1.0509 - emotion_output_loss: 1.0669 - gender_output_acc: 0.5497 - image_quality_output_acc: 0.5349 - age_output_acc: 0.3526 - weight_output_acc: 0.6042 - bag_output_acc: 0.5056 - footwear_output_acc: 0.4475 - pose_output_acc: 0.5994 - emotion_output_acc: 0.6803 - LRFinder: lr = 0.00735642
#  79/360 [=====>........................] - ETA: 3:23:32 - loss: 10.2808 - gender_output_loss: 0.8045 - image_quality_output_loss: 1.0452 - age_output_loss: 1.7276 - weight_output_loss: 1.2544 - bag_output_loss: 1.0994 - footwear_output_loss: 1.2406 - pose_output_loss: 1.0511 - emotion_output_loss: 1.0666 - gender_output_acc: 0.5498 - image_quality_output_acc: 0.5364 - age_output_acc: 0.3532 - weight_output_acc: 0.6040 - bag_output_acc: 0.5044 - footwear_output_acc: 0.4478 - pose_output_acc: 0.5989 - emotion_output_acc: 0.6796 - LRFinder: lr = 0.00754706
#  80/360 [=====>........................] - ETA: 3:22:49 - loss: 10.2730 - gender_output_loss: 0.8038 - image_quality_output_loss: 1.0480 - age_output_loss: 1.7246 - weight_output_loss: 1.2488 - bag_output_loss: 1.1008 - footwear_output_loss: 1.2381 - pose_output_loss: 1.0481 - emotion_output_loss: 1.0694 - gender_output_acc: 0.5492 - image_quality_output_acc: 0.5348 - age_output_acc: 0.3523 - weight_output_acc: 0.6051 - bag_output_acc: 0.5039 - footwear_output_acc: 0.4473 - pose_output_acc: 0.6000 - emotion_output_acc: 0.6781 - LRFinder: lr = 0.00774264
#  81/360 [=====>........................] - ETA: 3:22:07 - loss: 10.2536 - gender_output_loss: 0.8020 - image_quality_output_loss: 1.0472 - age_output_loss: 1.7213 - weight_output_loss: 1.2465 - bag_output_loss: 1.0989 - footwear_output_loss: 1.2361 - pose_output_loss: 1.0447 - emotion_output_loss: 1.0655 - gender_output_acc: 0.5494 - image_quality_output_acc: 0.5359 - age_output_acc: 0.3526 - weight_output_acc: 0.6049 - bag_output_acc: 0.5046 - footwear_output_acc: 0.4460 - pose_output_acc: 0.6015 - emotion_output_acc: 0.6790 - LRFinder: lr = 0.00794328
#  82/360 [=====>........................] - ETA: 3:21:24 - loss: 10.2414 - gender_output_loss: 0.8010 - image_quality_output_loss: 1.0463 - age_output_loss: 1.7187 - weight_output_loss: 1.2449 - bag_output_loss: 1.0977 - footwear_output_loss: 1.2335 - pose_output_loss: 1.0410 - emotion_output_loss: 1.0669 - gender_output_acc: 0.5492 - image_quality_output_acc: 0.5354 - age_output_acc: 0.3525 - weight_output_acc: 0.6044 - bag_output_acc: 0.5038 - footwear_output_acc: 0.4470 - pose_output_acc: 0.6033 - emotion_output_acc: 0.6787 - LRFinder: lr = 0.00814913
#  83/360 [=====>........................] - ETA: 3:20:41 - loss: 10.2315 - gender_output_loss: 0.7987 - image_quality_output_loss: 1.0466 - age_output_loss: 1.7168 - weight_output_loss: 1.2448 - bag_output_loss: 1.0959 - footwear_output_loss: 1.2301 - pose_output_loss: 1.0425 - emotion_output_loss: 1.0649 - gender_output_acc: 0.5508 - image_quality_output_acc: 0.5346 - age_output_acc: 0.3517 - weight_output_acc: 0.6035 - bag_output_acc: 0.5045 - footwear_output_acc: 0.4488 - pose_output_acc: 0.6024 - emotion_output_acc: 0.6796 - LRFinder: lr = 0.00836031
#  84/360 [======>.......................] - ETA: 3:19:58 - loss: 10.2217 - gender_output_loss: 0.7958 - image_quality_output_loss: 1.0457 - age_output_loss: 1.7144 - weight_output_loss: 1.2443 - bag_output_loss: 1.0953 - footwear_output_loss: 1.2270 - pose_output_loss: 1.0399 - emotion_output_loss: 1.0679 - gender_output_acc: 0.5525 - image_quality_output_acc: 0.5353 - age_output_acc: 0.3516 - weight_output_acc: 0.6031 - bag_output_acc: 0.5026 - footwear_output_acc: 0.4501 - pose_output_acc: 0.6031 - emotion_output_acc: 0.6789 - LRFinder: lr = 0.00857696
#  85/360 [======>.......................] - ETA: 3:19:16 - loss: 10.2146 - gender_output_loss: 0.7959 - image_quality_output_loss: 1.0452 - age_output_loss: 1.7142 - weight_output_loss: 1.2431 - bag_output_loss: 1.0936 - footwear_output_loss: 1.2225 - pose_output_loss: 1.0387 - emotion_output_loss: 1.0701 - gender_output_acc: 0.5522 - image_quality_output_acc: 0.5346 - age_output_acc: 0.3493 - weight_output_acc: 0.6022 - bag_output_acc: 0.5015 - footwear_output_acc: 0.4526 - pose_output_acc: 0.6033 - emotion_output_acc: 0.6772 - LRFinder: lr = 0.00879922
# ...
# 332/360 [==========================>...] - ETA: 20:16 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4899 - image_quality_output_acc: 0.5398 - age_output_acc: 0.2668 - weight_output_acc: 0.6210 - bag_output_acc: 0.4328 - footwear_output_acc: 0.4125 - pose_output_acc: 0.3822 - emotion_output_acc: 0.3909 - LRFinder: lr = 4.76186811
# 333/360 [==========================>...] - ETA: 19:32 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4896 - image_quality_output_acc: 0.5399 - age_output_acc: 0.2661 - weight_output_acc: 0.6210 - bag_output_acc: 0.4327 - footwear_output_acc: 0.4123 - pose_output_acc: 0.3817 - emotion_output_acc: 0.3898 - LRFinder: lr = 4.88526879
# 334/360 [==========================>...] - ETA: 18:49 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4893 - image_quality_output_acc: 0.5397 - age_output_acc: 0.2657 - weight_output_acc: 0.6211 - bag_output_acc: 0.4325 - footwear_output_acc: 0.4119 - pose_output_acc: 0.3809 - emotion_output_acc: 0.3888 - LRFinder: lr = 5.01186733
# 335/360 [==========================>...] - ETA: 18:05 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4891 - image_quality_output_acc: 0.5397 - age_output_acc: 0.2651 - weight_output_acc: 0.6210 - bag_output_acc: 0.4324 - footwear_output_acc: 0.4117 - pose_output_acc: 0.3802 - emotion_output_acc: 0.3878 - LRFinder: lr = 5.14174689
# 336/360 [===========================>..] - ETA: 17:22 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4885 - image_quality_output_acc: 0.5399 - age_output_acc: 0.2648 - weight_output_acc: 0.6211 - bag_output_acc: 0.4319 - footwear_output_acc: 0.4116 - pose_output_acc: 0.3797 - emotion_output_acc: 0.3869 - LRFinder: lr = 5.27499211
# 337/360 [===========================>..] - ETA: 16:38 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4885 - image_quality_output_acc: 0.5400 - age_output_acc: 0.2647 - weight_output_acc: 0.6213 - bag_output_acc: 0.4315 - footwear_output_acc: 0.4113 - pose_output_acc: 0.3790 - emotion_output_acc: 0.3860 - LRFinder: lr = 5.41169006
# 338/360 [===========================>..] - ETA: 15:55 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4882 - image_quality_output_acc: 0.5404 - age_output_acc: 0.2643 - weight_output_acc: 0.6215 - bag_output_acc: 0.4313 - footwear_output_acc: 0.4107 - pose_output_acc: 0.3783 - emotion_output_acc: 0.3852 - LRFinder: lr = 5.55193075
# 339/360 [===========================>..] - ETA: 15:12 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4883 - image_quality_output_acc: 0.5404 - age_output_acc: 0.2643 - weight_output_acc: 0.6216 - bag_output_acc: 0.4312 - footwear_output_acc: 0.4106 - pose_output_acc: 0.3778 - emotion_output_acc: 0.3843 - LRFinder: lr = 5.69580567
# 340/360 [===========================>..] - ETA: 14:28 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4884 - image_quality_output_acc: 0.5404 - age_output_acc: 0.2642 - weight_output_acc: 0.6215 - bag_output_acc: 0.4312 - footwear_output_acc: 0.4108 - pose_output_acc: 0.3770 - emotion_output_acc: 0.3835 - LRFinder: lr = 5.84340874
# 341/360 [===========================>..] - ETA: 13:45 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4882 - image_quality_output_acc: 0.5404 - age_output_acc: 0.2643 - weight_output_acc: 0.6218 - bag_output_acc: 0.4307 - footwear_output_acc: 0.4108 - pose_output_acc: 0.3762 - emotion_output_acc: 0.3827 - LRFinder: lr = 5.99483681
# 342/360 [===========================>..] - ETA: 13:01 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4882 - image_quality_output_acc: 0.5405 - age_output_acc: 0.2640 - weight_output_acc: 0.6219 - bag_output_acc: 0.4304 - footwear_output_acc: 0.4107 - pose_output_acc: 0.3755 - emotion_output_acc: 0.3820 - LRFinder: lr = 6.15018920
# 343/360 [===========================>..] - ETA: 12:18 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4878 - image_quality_output_acc: 0.5404 - age_output_acc: 0.2637 - weight_output_acc: 0.6215 - bag_output_acc: 0.4298 - footwear_output_acc: 0.4106 - pose_output_acc: 0.3751 - emotion_output_acc: 0.3811 - LRFinder: lr = 6.30956766
# 344/360 [===========================>..] - ETA: 11:34 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4881 - image_quality_output_acc: 0.5403 - age_output_acc: 0.2633 - weight_output_acc: 0.6216 - bag_output_acc: 0.4298 - footwear_output_acc: 0.4105 - pose_output_acc: 0.3746 - emotion_output_acc: 0.3805 - LRFinder: lr = 6.47307589
# 345/360 [===========================>..] - ETA: 10:51 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4880 - image_quality_output_acc: 0.5403 - age_output_acc: 0.2635 - weight_output_acc: 0.6218 - bag_output_acc: 0.4295 - footwear_output_acc: 0.4105 - pose_output_acc: 0.3738 - emotion_output_acc: 0.3798 - LRFinder: lr = 6.64082152
# 346/360 [===========================>..] - ETA: 10:07 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4875 - image_quality_output_acc: 0.5403 - age_output_acc: 0.2631 - weight_output_acc: 0.6218 - bag_output_acc: 0.4290 - footwear_output_acc: 0.4105 - pose_output_acc: 0.3735 - emotion_output_acc: 0.3793 - LRFinder: lr = 6.81291413
# 347/360 [===========================>..] - ETA: 9:24 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4871 - image_quality_output_acc: 0.5408 - age_output_acc: 0.2628 - weight_output_acc: 0.6218 - bag_output_acc: 0.4286 - footwear_output_acc: 0.4105 - pose_output_acc: 0.3729 - emotion_output_acc: 0.3788  - LRFinder: lr = 6.98946624
# 348/360 [============================>.] - ETA: 8:40 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4869 - image_quality_output_acc: 0.5411 - age_output_acc: 0.2626 - weight_output_acc: 0.6212 - bag_output_acc: 0.4277 - footwear_output_acc: 0.4104 - pose_output_acc: 0.3721 - emotion_output_acc: 0.3781 - LRFinder: lr = 7.17059377
# 349/360 [============================>.] - ETA: 7:57 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4866 - image_quality_output_acc: 0.5409 - age_output_acc: 0.2620 - weight_output_acc: 0.6211 - bag_output_acc: 0.4276 - footwear_output_acc: 0.4100 - pose_output_acc: 0.3715 - emotion_output_acc: 0.3776 - LRFinder: lr = 7.35641513
# 350/360 [============================>.] - ETA: 7:14 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4861 - image_quality_output_acc: 0.5410 - age_output_acc: 0.2614 - weight_output_acc: 0.6212 - bag_output_acc: 0.4272 - footwear_output_acc: 0.4099 - pose_output_acc: 0.3709 - emotion_output_acc: 0.3769 - LRFinder: lr = 7.54705211
# 351/360 [============================>.] - ETA: 6:30 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4859 - image_quality_output_acc: 0.5410 - age_output_acc: 0.2610 - weight_output_acc: 0.6210 - bag_output_acc: 0.4270 - footwear_output_acc: 0.4103 - pose_output_acc: 0.3705 - emotion_output_acc: 0.3761 - LRFinder: lr = 7.74262897
# 352/360 [============================>.] - ETA: 5:47 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4857 - image_quality_output_acc: 0.5413 - age_output_acc: 0.2610 - weight_output_acc: 0.6207 - bag_output_acc: 0.4271 - footwear_output_acc: 0.4094 - pose_output_acc: 0.3697 - emotion_output_acc: 0.3751 - LRFinder: lr = 7.94327437
# 353/360 [============================>.] - ETA: 5:03 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4859 - image_quality_output_acc: 0.5418 - age_output_acc: 0.2609 - weight_output_acc: 0.6211 - bag_output_acc: 0.4272 - footwear_output_acc: 0.4093 - pose_output_acc: 0.3692 - emotion_output_acc: 0.3742 - LRFinder: lr = 8.14911942
# 354/360 [============================>.] - ETA: 4:20 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4857 - image_quality_output_acc: 0.5418 - age_output_acc: 0.2609 - weight_output_acc: 0.6213 - bag_output_acc: 0.4267 - footwear_output_acc: 0.4091 - pose_output_acc: 0.3686 - emotion_output_acc: 0.3734 - LRFinder: lr = 8.36029863
# 355/360 [============================>.] - ETA: 3:36 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4854 - image_quality_output_acc: 0.5418 - age_output_acc: 0.2606 - weight_output_acc: 0.6216 - bag_output_acc: 0.4267 - footwear_output_acc: 0.4085 - pose_output_acc: 0.3680 - emotion_output_acc: 0.3727 - LRFinder: lr = 8.57695096
# 356/360 [============================>.] - ETA: 2:53 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4850 - image_quality_output_acc: 0.5420 - age_output_acc: 0.2602 - weight_output_acc: 0.6212 - bag_output_acc: 0.4261 - footwear_output_acc: 0.4084 - pose_output_acc: 0.3674 - emotion_output_acc: 0.3721 - LRFinder: lr = 8.79921727
# 357/360 [============================>.] - ETA: 2:10 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4844 - image_quality_output_acc: 0.5424 - age_output_acc: 0.2601 - weight_output_acc: 0.6215 - bag_output_acc: 0.4254 - footwear_output_acc: 0.4080 - pose_output_acc: 0.3669 - emotion_output_acc: 0.3714 - LRFinder: lr = 9.02724336
# 358/360 [============================>.] - ETA: 1:26 - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4844 - image_quality_output_acc: 0.5422 - age_output_acc: 0.2600 - weight_output_acc: 0.6219 - bag_output_acc: 0.4253 - footwear_output_acc: 0.4075 - pose_output_acc: 0.3662 - emotion_output_acc: 0.3710 - LRFinder: lr = 9.26117890
# 359/360 [============================>.] - ETA: 43s - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4843 - image_quality_output_acc: 0.5420 - age_output_acc: 0.2597 - weight_output_acc: 0.6218 - bag_output_acc: 0.4251 - footwear_output_acc: 0.4079 - pose_output_acc: 0.3658 - emotion_output_acc: 0.3703  - LRFinder: lr = 9.50117655
#  - LRFinder: lr = 9.74739380
# 360/360 [==============================] - 16403s 46s/step - loss: nan - gender_output_loss: nan - image_quality_output_loss: nan - age_output_loss: nan - weight_output_loss: nan - bag_output_loss: nan - footwear_output_loss: nan - pose_output_loss: nan - emotion_output_loss: nan - gender_output_acc: 0.4840 - image_quality_output_acc: 0.5422 - age_output_acc: 0.2597 - weight_output_acc: 0.6217 - bag_output_acc: 0.4250 - footwear_output_acc: 0.4083 - pose_output_acc: 0.3651 - emotion_output_acc: 0.3695 - val_loss: nan - val_gender_output_loss: nan - val_image_quality_output_loss: nan - val_age_output_loss: nan - val_weight_output_loss: nan - val_bag_output_loss: nan - val_footwear_output_loss: nan - val_pose_output_loss: nan - val_emotion_output_loss: nan - val_gender_output_acc: 0.4355 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.1930 - val_weight_output_acc: 0.6399 - val_bag_output_acc: 0.3447 - val_footwear_output_acc: 0.3656 - val_pose_output_acc: 0.1562 - val_emotion_output_acc: 0.1210

# %%
lr_finder.plot_schedule(clip_beginning=10, clip_endding=5)

#scores = model.evaluate(X_test, Y_test, batch_size=batch_size)
#for score, metric_name in zip(scores, model.metrics_names):
    #print("%s : %0.4f" % (metric_name, score))

# %%
# Ensure that number of epochs = 1 when calling fit()
#model.fit(X, Y, epochs=1, batch_size=batch_size, callbacks=[clr_triangular])
